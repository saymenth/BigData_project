# %% [markdown]
# # Data Traffic

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('Traffic_Volume_Counts_20240710.csv')

# %%
df.head(2)
# Out:
#    ID  SegmentID  Roadway Name         From                To Direction  \
# 0   1      15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 1   2      15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
#
#          Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  ...  2:00-3:00PM  \
# 0  01/09/2012           20.0         10.0         11.0  ...        104.0
# 1  01/10/2012           21.0         16.0          8.0  ...        102.0
#
#    3:00-4:00PM  4:00-5:00PM  5:00-6:00PM  6:00-7:00PM  7:00-8:00PM  \
# 0        105.0        147.0        120.0         91.0         83.0
# 1         98.0        133.0        131.0         95.0         73.0
#
#    8:00-9:00PM  9:00-10:00PM  10:00-11:00PM  11:00-12:00AM
# 0         74.0          49.0           42.0           42.0
# 1         70.0          63.0           42.0           35.0
#
# [2 rows x 31 columns]

# %%
# Drop columns -> 'SegmentID', 'Direction', 'From', 'To'
df = df.drop(columns=['SegmentID', 'Direction', 'From', 'To'], axis=0)

# %%
# df.iloc[:, 3:15][0:3]
# df.iloc[:, 15:27][0:3]

# %%
# get mean total traffic dari jam 1-12 dan 13-24
pagi_12 = df.iloc[:, 3:15].mean(axis=1)
malam_12 = df.iloc[:, 15:27].mean(axis=1)

# %%
# drop columns data total traffic dari jam 1-24
df.drop(df.columns[3:33], axis=1, inplace=True)

# %%
# assign data mean traffic ke dataframe
df['pagi_12'] = pagi_12
df['malam_12'] = malam_12

# %%
df.head(3)
# Out:
#    ID  Roadway Name        Date    pagi_12   malam_12
# 0   1  BEACH STREET  01/09/2012  41.083333  86.333333
# 1   2  BEACH STREET  01/10/2012  34.500000  84.166667
# 2   3  BEACH STREET  01/11/2012  38.833333  92.333333

# %%
df.tail(3)
# Out:
#         ID      Roadway Name        Date     pagi_12    malam_12
# 42753  373  WEST 49th STREET  11/20/2020  103.666667  179.083333
# 42754  373  WEST 49th STREET  11/21/2020   70.333333  161.583333
# 42755  373  WEST 49th STREET  11/22/2020   68.250000  156.416667

# %%
# ubah tipe data date dari string ke datetime -> find yang year 2012 -> tipe data akan datetime jika mau diubah string lagi bolehhh
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')
df = df[df['Date'].dt.year == 2012]

# %%
df
# Out:
#        ID              Roadway Name       Date    pagi_12    malam_12
# 0       1              BEACH STREET 2012-01-09  41.083333   86.333333
# 1       2              BEACH STREET 2012-01-10  34.500000   84.166667
# 2       3              BEACH STREET 2012-01-11  38.833333   92.333333
# 3       4              BEACH STREET 2012-01-12  38.333333   91.583333
# 4       5              BEACH STREET 2012-01-13  43.166667   95.083333
# ...   ...                       ...        ...        ...         ...
# 9295  374               FAIRMONT PL 2012-10-28  29.000000   41.750000
# 9315  376  THROGS NECK EXPWY SER RD 2012-10-27  45.166667  215.833333
# 9316  376  THROGS NECK EXPWY SER RD 2012-10-28  56.416667  157.583333
# 9324  377                  E 177 ST 2012-10-27  46.333333  222.333333
# 9325  377                  E 177 ST 2012-10-28  53.333333  155.333333
#
# [8051 rows x 5 columns]

# %%
# 2 nilai output -> 12 jam 12 akhir -> 12 jam hujan, temperature, humidity -> 12 akhir

# %%
df.to_excel('testing.xlsx')

# %%
# preprocess perludicek untuk kolom roadway dan date
# karena masih ada data yang berulang


'''
    1. data pagi_12 dan malam_12 perlu dicek karena masih ada yang kosong dan 0 -> bisa jadi karena pada saat pakai function mean()
    ada data yang nilainya 0 atau nan
    2. preprocess perlu dicek untuk kolom roadway dan date -> karena masih ada data pada lokasi dengan jam yang sama (berulang)
    3. rapi dijoin beradasarkan date
'''

# %% [markdown]
# # Data Weather

# %%
df_weather = pd.read_csv('weatherHistory.csv')

# %%
df_weather.head(14)
# Out:
#                    Formatted Date        Summary Precip Type  Temperature (C)  \
# 0   2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1   2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2   2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3   2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4   2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5   2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 6   2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 7   2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 8   2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9   2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
# 10  2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain        16.016667
# 11  2006-04-01 11:00:00.000 +0200  Partly Cloudy        rain        17.144444
# 12  2006-04-01 12:00:00.000 +0200  Partly Cloudy        rain        17.800000
# 13  2006-04-01 13:00:00.000 +0200  Partly Cloudy        rain        17.333333
#
#     Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                   7.388889      0.89            14.1197
# 1                   7.227778      0.86            14.2646
# 2                   9.377778      0.89             3.9284
# 3                   5.944444      0.83            14.1036
# 4                   6.977778      0.83            11.0446
# 5                   7.111111      0.85            13.9587
# 6                   5.522222      0.95            12.3648
# 7                   6.527778      0.89            14.1519
# 8                  10.822222      0.82            11.3183
# 9                  13.772222      0.72            12.5258
# 10                 16.016667      0.67            17.5651
# 11                 17.144444      0.54            19.7869
# 12                 17.800000      0.55            21.9443
# 13                 17.333333      0.51            20.6885
#
#     Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                    251.0          15.8263         0.0               1015.13
# 1                    259.0          15.8263         0.0               1015.63
# 2                    204.0          14.9569         0.0               1015.94
# 3                    269.0          15.8263         0.0               1016.41
# 4                    259.0          15.8263         0.0               1016.51
# 5                    258.0          14.9569         0.0               1016.66
# 6                    259.0           9.9820         0.0               1016.72
# 7                    260.0           9.9820         0.0               1016.84
# 8                    259.0           9.9820         0.0               1017.37
# 9                    279.0           9.9820         0.0               1017.22
# 10                   290.0          11.2056         0.0               1017.42
# 11                   316.0          11.4471         0.0               1017.74
# 12                   281.0          11.2700         0.0               1017.59
# 13                   289.0          11.2700         0.0               1017.48
#
#                         Daily Summary
# 0   Partly cloudy throughout the day.
# 1   Partly cloudy throughout the day.
# 2   Partly cloudy throughout the day.
# 3   Partly cloudy throughout the day.
# 4   Partly cloudy throughout the day.
# 5   Partly cloudy throughout the day.
# 6   Partly cloudy throughout the day.
# 7   Partly cloudy throughout the day.
# 8   Partly cloudy throughout the day.
# 9   Partly cloudy throughout the day.
# 10  Partly cloudy throughout the day.
# 11  Partly cloudy throughout the day.
# 12  Partly cloudy throughout the day.
# 13  Partly cloudy throughout the day.

# %%
df_weather.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
'''
    1. get data pada tahun 2012 -> diambil penuh dari bulan 1 sampai 12
    2. cek deskripsi kolom -> untuk kebutuhan training
    3. prepoessing 12 pagi 12 malam
    4. join berdasarkan hari dan bulan yang sama
'''

# %% [markdown]
# # Stop

# %%
df['Roadway Name'].nunique()
# Out:
# 1276

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y', errors='coerce')

df.info()

# %%
df.head()

# %%
type(df['Date'][0])
# Out:
# str

# %%
df.head(3)
# Out:
#    ID  SegmentID  Roadway Name         From                To Direction  \
# 0   1      15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 1   2      15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 2   3      15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
#
#          Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  ...  2:00-3:00PM  \
# 0  01/09/2012           20.0         10.0         11.0  ...        104.0
# 1  01/10/2012           21.0         16.0          8.0  ...        102.0
# 2  01/11/2012           27.0         14.0          6.0  ...        115.0
#
#    3:00-4:00PM  4:00-5:00PM  5:00-6:00PM  6:00-7:00PM  7:00-8:00PM  \
# 0        105.0        147.0        120.0         91.0         83.0
# 1         98.0        133.0        131.0         95.0         73.0
# 2        115.0        130.0        143.0        106.0         89.0
#
#    8:00-9:00PM  9:00-10:00PM  10:00-11:00PM  11:00-12:00AM
# 0         74.0          49.0           42.0           42.0
# 1         70.0          63.0           42.0           35.0
# 2         68.0          64.0           56.0           43.0
#
# [3 rows x 31 columns]

# %%
date_to_check = '01/09/2012'
row = df.loc[df['Date'] == date_to_check]
row
# Out:
#       ID  SegmentID        Roadway Name                From                To  \
# 0      1      15540        BEACH STREET         UNION PLACE  VAN DUZER STREET
# 6      7      15540        BEACH STREET         UNION PLACE  VAN DUZER STREET
# 12    13      12809   LITTLE CLOVE ROAD  NORTHERN BOULEVARD    BRISTOL AVENUE
# 18    19      12809   LITTLE CLOVE ROAD  NORTHERN BOULEVARD    BRISTOL AVENUE
# 24    25      14723  NARROWS ROAD SOUTH     HASTINGS STREET     GARSON AVENUE
# ..   ...        ...                 ...                 ...               ...
# 742  741     112135            Amboy Rd           Beach Ave            3rd St
# 757  756       4234       ANNADALE ROAD         LADD AVENUE      BERRY AVENUE
# 762  761       4234       ANNADALE ROAD         LADD AVENUE      BERRY AVENUE
# 767  766       3115        ARDEN AVENUE     SINCLAIR AVENUE    SHELDON AVENUE
# 772  771       3115        ARDEN AVENUE     SINCLAIR AVENUE    SHELDON AVENUE
#
#     Direction        Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  ...  \
# 0          NB  01/09/2012           20.0         10.0         11.0  ...
# 6          SB  01/09/2012           27.0         12.0         12.0  ...
# 12         EB  01/09/2012           21.0         11.0          2.0  ...
# 18         WB  01/09/2012           18.0          7.0          7.0  ...
# 24         SB  01/09/2012           15.0         13.0          5.0  ...
# ..        ...         ...            ...          ...          ...  ...
# 742        WB  01/09/2012           91.0         43.0         31.0  ...
# 757        NB  01/09/2012           19.0          9.0          6.0  ...
# 762        SB  01/09/2012           12.0          8.0          2.0  ...
# 767        NB  01/09/2012           60.0         26.0         25.0  ...
# 772        SB  01/09/2012           51.0         26.0         15.0  ...
#
#      2:00-3:00PM  3:00-4:00PM  4:00-5:00PM  5:00-6:00PM  6:00-7:00PM  \
# 0          104.0        105.0        147.0        120.0         91.0
# 6          165.0        197.0        152.0        174.0        128.0
# 12         281.0        251.0        218.0        219.0        175.0
# 18         280.0        326.0        496.0        301.0        182.0
# 24         162.0        137.0        145.0        105.0        108.0
# ..           ...          ...          ...          ...          ...
# 742        599.0        655.0        738.0        757.0        618.0
# 757        132.0        161.0        131.0        164.0        130.0
# 762        122.0        111.0        134.0        128.0        129.0
# 767        480.0        534.0        499.0        504.0        439.0
# 772        304.0        322.0        344.0        300.0        281.0
#
#      7:00-8:00PM  8:00-9:00PM  9:00-10:00PM  10:00-11:00PM  11:00-12:00AM
# 0           83.0         74.0          49.0           42.0           42.0
# 6           95.0         87.0          73.0           57.0           42.0
# 12         150.0        102.0          77.0           49.0           36.0
# 18         172.0         77.0          73.0           38.0           21.0
# 24          85.0         85.0          59.0           39.0           33.0
# ..           ...          ...           ...            ...            ...
# 742        519.0        389.0         305.0          211.0          159.0
# 757        141.0         77.0          55.0           49.0           27.0
# 762        103.0         63.0          67.0           48.0           18.0
# 767        400.0        316.0         229.0          133.0           98.0
# 772        237.0        179.0         166.0          105.0           91.0
#
# [102 rows x 31 columns]

# %%
df = df.drop(columns=['From', 'To'], axis=0)

# %%
unique =

# %%
df
# Out:
#         ID  SegmentID      Roadway Name Direction        Date  12:00-1:00 AM  \
# 0        1      15540      BEACH STREET        NB  01/09/2012           20.0
# 1        2      15540      BEACH STREET        NB  01/10/2012           21.0
# 2        3      15540      BEACH STREET        NB  01/11/2012           27.0
# 3        4      15540      BEACH STREET        NB  01/12/2012           22.0
# 4        5      15540      BEACH STREET        NB  01/13/2012           31.0
# ...    ...        ...               ...       ...         ...            ...
# 42751  373      35832  WEST 49th STREET        WB  11/18/2020           68.0
# 42752  373      35832  WEST 49th STREET        WB  11/19/2020           71.0
# 42753  373      35832  WEST 49th STREET        WB  11/20/2020          111.0
# 42754  373      35832  WEST 49th STREET        WB  11/21/2020          129.0
# 42755  373      35832  WEST 49th STREET        WB  11/22/2020          159.0
#
#        1:00-2:00AM  2:00-3:00AM  3:00-4:00AM  4:00-5:00AM  ...  2:00-3:00PM  \
# 0             10.0         11.0         14.0         13.0  ...        104.0
# 1             16.0          8.0          6.0         13.0  ...        102.0
# 2             14.0          6.0          5.0         12.0  ...        115.0
# 3              7.0          7.0          8.0         11.0  ...         71.0
# 4             17.0          7.0          5.0         13.0  ...        113.0
# ...            ...          ...          ...          ...  ...          ...
# 42751         63.0         31.0         24.0         36.0  ...        152.0
# 42752         59.0         42.0         28.0         26.0  ...        166.0
# 42753         79.0         54.0         27.0         25.0  ...        157.0
# 42754         95.0         63.0         45.0         35.0  ...        139.0
# 42755        109.0         77.0         37.0         24.0  ...        151.0
#
#        3:00-4:00PM  4:00-5:00PM  5:00-6:00PM  6:00-7:00PM  7:00-8:00PM  \
# 0            105.0        147.0        120.0         91.0         83.0
# 1             98.0        133.0        131.0         95.0         73.0
# 2            115.0        130.0        143.0        106.0         89.0
# 3            127.0        122.0        144.0        122.0         76.0
# 4            126.0        133.0        135.0        102.0        106.0
# ...            ...          ...          ...          ...          ...
# 42751        177.0        162.0        164.0        183.0        173.0
# 42752        162.0        187.0        182.0        180.0        190.0
# 42753        186.0        170.0        158.0        194.0        196.0
# 42754        147.0        153.0        183.0        163.0        184.0
# 42755        176.0        152.0        146.0        181.0        177.0
#
#        8:00-9:00PM  9:00-10:00PM  10:00-11:00PM  11:00-12:00AM
# 0             74.0          49.0           42.0           42.0
# 1             70.0          63.0           42.0           35.0
# 2             68.0          64.0           56.0           43.0
# 3             64.0          58.0           64.0           43.0
# 4             58.0          58.0           55.0           54.0
# ...            ...           ...            ...            ...
# 42751        143.0         113.0          127.0          133.0
# 42752        162.0         155.0          234.0          166.0
# 42753        222.0         174.0          182.0          178.0
# 42754        183.0         169.0          187.0          211.0
# 42755        160.0         162.0          147.0          137.0
#
# [42756 rows x 29 columns]

# %%
import datetime
t = datetime.datetime()
t.strftime('%m/%d/%Y')
